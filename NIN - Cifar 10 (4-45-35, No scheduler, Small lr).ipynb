# %% [markdown]
# # NIN
#
# # 1. Environment Setup
# ## 1.0. Check GPU

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %% [markdown]
# ## 1.1. Install Pytorch and torchvision

# %%
# !pip install torch==1.7.1+cu110 torchvision==0.8.2+cu110 torchaudio===0.7.2 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: torch==1.7.1+cu110 in /usr/local/lib/python3.6/dist-packages (1.7.1+cu110)
# Requirement already satisfied: torchvision==0.8.2+cu110 in /usr/local/lib/python3.6/dist-packages (0.8.2+cu110)
# Requirement already satisfied: torchaudio===0.7.2 in /usr/local/lib/python3.6/dist-packages (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch==1.7.1+cu110) (1.19.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch==1.7.1+cu110) (3.7.4.3)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from torch==1.7.1+cu110) (0.8)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.8.2+cu110) (8.0.1)
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# ## 1.2. Import

# %%
import train

import torch
import torchvision
import torchvision.transforms as transforms

import matplotlib.pyplot as plt

# Ignore Warning
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # 2. Data Preprocessing

# %%
batch_size = 128

# %%
train_transform = transforms.Compose([
    transforms.Pad(padding=4), transforms.Resize(45), transforms.RandomCrop(35), transforms.RandomHorizontalFlip(),
    transforms.ToTensor(), transforms.Normalize(mean=[0.4921, 0.4828, 0.4474], std=[0.1950, 0.1922, 0.1940])])

test_transform = transforms.Compose([
    transforms.Pad(padding=4), transforms.Resize(45), transforms.CenterCrop(35),
    transforms.ToTensor(), transforms.Normalize(mean=[0.4921, 0.4828, 0.4474], std=[0.1950, 0.1922, 0.1940])])

train_dataset = torchvision.datasets.CIFAR10('../Dataset/cifar10/', train=True, download=True, transform=train_transform)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)

test_dataset = torchvision.datasets.CIFAR10('../Dataset/cifar10/', train=False, download=True, transform=test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # 3. Train Model

# %%
num_classes = 10

gpu_id = 4
print_freq = 100
epoch_print = 80

save = False
epochs = 8001

lr = 0.001
momentum = 0.9
weight_decay = 0.00001

# %%
NIN = train.NIN(num_classes=num_classes, gpu_id=gpu_id, print_freq=print_freq, epoch_print=epoch_print)

# %%
NIN.train(train_loader, test_loader, save, epochs, lr, momentum, weight_decay)
# Out:
# Epoch 1 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 2.3061, Test Loss : 2.3006, Train Acc : 10.1562, Test Acc : 13.5800
# Iteration : 200 - Train Loss : 2.3057, Test Loss : 2.2991, Train Acc : 14.0625, Test Acc : 11.7300
# Iteration : 300 - Train Loss : 2.3013, Test Loss : 2.2932, Train Acc : 6.2500, Test Acc : 11.7100
# Epoch 81 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 2.0564, Test Loss : 2.0378, Train Acc : 42.1875, Test Acc : 42.1100
# Iteration : 200 - Train Loss : 2.0591, Test Loss : 2.0464, Train Acc : 39.0625, Test Acc : 41.3200
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 2.0682, Test Loss : 2.0336, Train Acc : 38.2812, Test Acc : 42.5400
# Epoch 161 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.9098, Test Loss : 1.9690, Train Acc : 57.0312, Test Acc : 48.6900
# Iteration : 200 - Train Loss : 2.0140, Test Loss : 1.9738, Train Acc : 43.7500, Test Acc : 48.3900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 2.0743, Test Loss : 1.9678, Train Acc : 38.2812, Test Acc : 48.9400
# Epoch 241 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 2.0452, Test Loss : 1.9186, Train Acc : 41.4062, Test Acc : 53.9000
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.8784, Test Loss : 1.9145, Train Acc : 58.5938, Test Acc : 54.4500
# Iteration : 300 - Train Loss : 1.9894, Test Loss : 1.9226, Train Acc : 47.6562, Test Acc : 53.7600
# Epoch 321 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.9712, Test Loss : 1.8867, Train Acc : 50.0000, Test Acc : 57.2100
# Iteration : 200 - Train Loss : 1.8878, Test Loss : 1.8886, Train Acc : 56.2500, Test Acc : 57.0300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.9726, Test Loss : 1.8824, Train Acc : 48.4375, Test Acc : 57.8800
# Epoch 401 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.9206, Test Loss : 1.8586, Train Acc : 51.5625, Test Acc : 60.2000
# Iteration : 200 - Train Loss : 1.9624, Test Loss : 1.8609, Train Acc : 47.6562, Test Acc : 59.8400
# Iteration : 300 - Train Loss : 1.9143, Test Loss : 1.8597, Train Acc : 56.2500, Test Acc : 60.0800
# Epoch 481 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.8368, Test Loss : 1.8403, Train Acc : 62.5000, Test Acc : 61.9200
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.7791, Test Loss : 1.8396, Train Acc : 69.5312, Test Acc : 62.0100
# Iteration : 300 - Train Loss : 1.8853, Test Loss : 1.8426, Train Acc : 57.0312, Test Acc : 61.5500
# Epoch 561 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.8409, Test Loss : 1.8236, Train Acc : 61.7188, Test Acc : 63.6800
# Iteration : 200 - Train Loss : 1.8400, Test Loss : 1.8256, Train Acc : 61.7188, Test Acc : 63.3900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.9012, Test Loss : 1.8217, Train Acc : 54.6875, Test Acc : 63.8800
# Epoch 641 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.8206, Test Loss : 1.8114, Train Acc : 64.0625, Test Acc : 64.8100
# Iteration : 200 - Train Loss : 1.8471, Test Loss : 1.8154, Train Acc : 61.7188, Test Acc : 64.3900
# Iteration : 300 - Train Loss : 1.8409, Test Loss : 1.8131, Train Acc : 61.7188, Test Acc : 64.8100
# Epoch 721 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.8207, Test Loss : 1.8029, Train Acc : 64.0625, Test Acc : 65.6800
# Iteration : 200 - Train Loss : 1.8607, Test Loss : 1.8065, Train Acc : 60.9375, Test Acc : 65.3700
# Iteration : 300 - Train Loss : 1.8766, Test Loss : 1.8041, Train Acc : 58.5938, Test Acc : 65.6000
# Epoch 801 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.8028, Test Loss : 1.7979, Train Acc : 64.8438, Test Acc : 66.1900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.8346, Test Loss : 1.7952, Train Acc : 63.2812, Test Acc : 66.4800
# Iteration : 300 - Train Loss : 1.7852, Test Loss : 1.8008, Train Acc : 65.6250, Test Acc : 65.9600
# Epoch 881 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.8763, Test Loss : 1.7929, Train Acc : 58.5938, Test Acc : 66.6600
# Iteration : 200 - Train Loss : 1.8426, Test Loss : 1.7925, Train Acc : 60.1562, Test Acc : 66.6500
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.7745, Test Loss : 1.7904, Train Acc : 67.9688, Test Acc : 67.1800
# Epoch 961 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.7836, Test Loss : 1.7869, Train Acc : 67.9688, Test Acc : 67.3700
# Iteration : 200 - Train Loss : 1.7825, Test Loss : 1.7875, Train Acc : 67.9688, Test Acc : 67.1700
# Iteration : 300 - Train Loss : 1.8379, Test Loss : 1.7883, Train Acc : 61.7188, Test Acc : 67.2000
# Epoch 1041 Started...
# Iteration : 100 - Train Loss : 1.7902, Test Loss : 1.7851, Train Acc : 67.1875, Test Acc : 67.3100
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.7560, Test Loss : 1.7831, Train Acc : 71.0938, Test Acc : 67.6300
# Iteration : 300 - Train Loss : 1.7802, Test Loss : 1.7839, Train Acc : 68.7500, Test Acc : 67.6000
# Epoch 1121 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.8616, Test Loss : 1.7842, Train Acc : 59.3750, Test Acc : 67.6600
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.8170, Test Loss : 1.7788, Train Acc : 64.0625, Test Acc : 68.1700
# Iteration : 300 - Train Loss : 1.8420, Test Loss : 1.7797, Train Acc : 63.2812, Test Acc : 67.9900
# Epoch 1201 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.7805, Test Loss : 1.7782, Train Acc : 67.1875, Test Acc : 68.3200
# Iteration : 200 - Train Loss : 1.7770, Test Loss : 1.7787, Train Acc : 67.9688, Test Acc : 68.2800
# Iteration : 300 - Train Loss : 1.8108, Test Loss : 1.7779, Train Acc : 64.8438, Test Acc : 68.1800
# Epoch 1281 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.8167, Test Loss : 1.7747, Train Acc : 64.0625, Test Acc : 68.5600
# Iteration : 200 - Train Loss : 1.8055, Test Loss : 1.7766, Train Acc : 64.0625, Test Acc : 68.3300
# Iteration : 300 - Train Loss : 1.7881, Test Loss : 1.7817, Train Acc : 67.1875, Test Acc : 67.9300
# Epoch 1361 Started...
# Iteration : 100 - Train Loss : 1.8314, Test Loss : 1.7756, Train Acc : 61.7188, Test Acc : 68.3100
# Iteration : 200 - Train Loss : 1.7853, Test Loss : 1.7742, Train Acc : 67.9688, Test Acc : 68.4900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.7726, Test Loss : 1.7728, Train Acc : 70.3125, Test Acc : 68.6600
# Epoch 1441 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.8430, Test Loss : 1.7708, Train Acc : 61.7188, Test Acc : 68.9200
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.7965, Test Loss : 1.7699, Train Acc : 67.1875, Test Acc : 69.0200
# Iteration : 300 - Train Loss : 1.7467, Test Loss : 1.7695, Train Acc : 72.6562, Test Acc : 69.0100
# Epoch 1521 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.8022, Test Loss : 1.7675, Train Acc : 65.6250, Test Acc : 69.2200
# Iteration : 200 - Train Loss : 1.7605, Test Loss : 1.7704, Train Acc : 70.3125, Test Acc : 68.9300
# Iteration : 300 - Train Loss : 1.7644, Test Loss : 1.7678, Train Acc : 68.7500, Test Acc : 69.2100
# Epoch 1601 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.7796, Test Loss : 1.7673, Train Acc : 67.9688, Test Acc : 69.3800
# Iteration : 200 - Train Loss : 1.8118, Test Loss : 1.7680, Train Acc : 64.0625, Test Acc : 69.2200
# Iteration : 300 - Train Loss : 1.7457, Test Loss : 1.7673, Train Acc : 71.0938, Test Acc : 69.3100
# Epoch 1681 Started...
# Iteration : 100 - Train Loss : 1.7565, Test Loss : 1.7671, Train Acc : 70.3125, Test Acc : 69.2800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.8234, Test Loss : 1.7653, Train Acc : 64.0625, Test Acc : 69.4900
# Iteration : 300 - Train Loss : 1.7386, Test Loss : 1.7644, Train Acc : 71.8750, Test Acc : 69.4600
# Epoch 1761 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.7833, Test Loss : 1.7631, Train Acc : 67.1875, Test Acc : 69.6000
# Iteration : 200 - Train Loss : 1.7558, Test Loss : 1.7645, Train Acc : 71.0938, Test Acc : 69.4700
# Iteration : 300 - Train Loss : 1.7803, Test Loss : 1.7648, Train Acc : 67.1875, Test Acc : 69.5700
# Epoch 1841 Started...
# Iteration : 100 - Train Loss : 1.7666, Test Loss : 1.7642, Train Acc : 68.7500, Test Acc : 69.3900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.7148, Test Loss : 1.7616, Train Acc : 74.2188, Test Acc : 69.9200
# Iteration : 300 - Train Loss : 1.8111, Test Loss : 1.7609, Train Acc : 64.8438, Test Acc : 69.9000
# Epoch 1921 Started...
# Iteration : 100 - Train Loss : 1.7755, Test Loss : 1.7620, Train Acc : 67.9688, Test Acc : 69.7600
# Iteration : 200 - Train Loss : 1.7962, Test Loss : 1.7626, Train Acc : 66.4062, Test Acc : 69.7900
# Iteration : 300 - Train Loss : 1.8014, Test Loss : 1.7633, Train Acc : 65.6250, Test Acc : 69.6700
# Epoch 2001 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.6942, Test Loss : 1.7561, Train Acc : 77.3438, Test Acc : 70.4800
# Iteration : 200 - Train Loss : 1.7068, Test Loss : 1.7604, Train Acc : 75.7812, Test Acc : 69.9500
# Iteration : 300 - Train Loss : 1.7752, Test Loss : 1.7575, Train Acc : 68.7500, Test Acc : 70.2200
# Epoch 2081 Started...
# Iteration : 100 - Train Loss : 1.7810, Test Loss : 1.7601, Train Acc : 68.7500, Test Acc : 70.0100
# Iteration : 200 - Train Loss : 1.7086, Test Loss : 1.7582, Train Acc : 75.0000, Test Acc : 70.2600
# Iteration : 300 - Train Loss : 1.7994, Test Loss : 1.7592, Train Acc : 64.8438, Test Acc : 70.0300
# Epoch 2161 Started...
# Iteration : 100 - Train Loss : 1.8373, Test Loss : 1.7612, Train Acc : 61.7188, Test Acc : 70.0000
# Iteration : 200 - Train Loss : 1.8064, Test Loss : 1.7612, Train Acc : 64.0625, Test Acc : 69.9800
# Iteration : 300 - Train Loss : 1.7663, Test Loss : 1.7563, Train Acc : 68.7500, Test Acc : 70.4700
# Epoch 2241 Started...
# Iteration : 100 - Train Loss : 1.6886, Test Loss : 1.7570, Train Acc : 78.1250, Test Acc : 70.3600
# Iteration : 200 - Train Loss : 1.7405, Test Loss : 1.7571, Train Acc : 71.0938, Test Acc : 70.4700
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.7013, Test Loss : 1.7537, Train Acc : 75.7812, Test Acc : 70.7200
# Epoch 2321 Started...
# Iteration : 100 - Train Loss : 1.7514, Test Loss : 1.7577, Train Acc : 71.0938, Test Acc : 70.3600
# Iteration : 200 - Train Loss : 1.7831, Test Loss : 1.7531, Train Acc : 67.9688, Test Acc : 70.6200
# Iteration : 300 - Train Loss : 1.7962, Test Loss : 1.7543, Train Acc : 65.6250, Test Acc : 70.6200
# Epoch 2401 Started...
# Iteration : 100 - Train Loss : 1.6987, Test Loss : 1.7564, Train Acc : 77.3438, Test Acc : 70.2900
# Iteration : 200 - Train Loss : 1.7908, Test Loss : 1.7530, Train Acc : 65.6250, Test Acc : 70.7100
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.7160, Test Loss : 1.7528, Train Acc : 74.2188, Test Acc : 70.8400
# Epoch 2481 Started...
# Iteration : 100 - Train Loss : 1.7202, Test Loss : 1.7582, Train Acc : 75.0000, Test Acc : 70.0800
# Iteration : 200 - Train Loss : 1.7181, Test Loss : 1.7533, Train Acc : 74.2188, Test Acc : 70.7100
# Iteration : 300 - Train Loss : 1.7603, Test Loss : 1.7548, Train Acc : 69.5312, Test Acc : 70.6800
# Epoch 2561 Started...
# Iteration : 100 - Train Loss : 1.7890, Test Loss : 1.7566, Train Acc : 66.4062, Test Acc : 70.3500
# Iteration : 200 - Train Loss : 1.7535, Test Loss : 1.7539, Train Acc : 70.3125, Test Acc : 70.5700
# Iteration : 300 - Train Loss : 1.7258, Test Loss : 1.7533, Train Acc : 73.4375, Test Acc : 70.6200
# Epoch 2641 Started...
# Iteration : 100 - Train Loss : 1.7402, Test Loss : 1.7511, Train Acc : 71.8750, Test Acc : 70.8300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.7529, Test Loss : 1.7502, Train Acc : 71.0938, Test Acc : 71.0900
# Iteration : 300 - Train Loss : 1.7245, Test Loss : 1.7500, Train Acc : 74.2188, Test Acc : 70.9800
# Epoch 2721 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.6481, Test Loss : 1.7489, Train Acc : 81.2500, Test Acc : 71.1000
# Iteration : 200 - Train Loss : 1.7466, Test Loss : 1.7497, Train Acc : 71.8750, Test Acc : 71.0900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.7670, Test Loss : 1.7485, Train Acc : 68.7500, Test Acc : 71.1800
# Epoch 2801 Started...
# Iteration : 100 - Train Loss : 1.7305, Test Loss : 1.7500, Train Acc : 73.4375, Test Acc : 71.1700
# Iteration : 200 - Train Loss : 1.7642, Test Loss : 1.7488, Train Acc : 69.5312, Test Acc : 71.1000
# Iteration : 300 - Train Loss : 1.7782, Test Loss : 1.7503, Train Acc : 67.9688, Test Acc : 70.9600
# Epoch 2881 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.7328, Test Loss : 1.7462, Train Acc : 71.8750, Test Acc : 71.3900
# Iteration : 200 - Train Loss : 1.7170, Test Loss : 1.7503, Train Acc : 74.2188, Test Acc : 70.9600
# Iteration : 300 - Train Loss : 1.7086, Test Loss : 1.7496, Train Acc : 75.7812, Test Acc : 71.0700
# Epoch 2961 Started...
# Iteration : 100 - Train Loss : 1.7253, Test Loss : 1.7489, Train Acc : 75.0000, Test Acc : 71.1500
# Iteration : 200 - Train Loss : 1.7818, Test Loss : 1.7483, Train Acc : 67.1875, Test Acc : 71.1400
# Iteration : 300 - Train Loss : 1.7205, Test Loss : 1.7467, Train Acc : 74.2188, Test Acc : 71.3900
# Epoch 3041 Started...
# Iteration : 100 - Train Loss : 1.7283, Test Loss : 1.7497, Train Acc : 72.6562, Test Acc : 71.0500
# Iteration : 200 - Train Loss : 1.6720, Test Loss : 1.7480, Train Acc : 78.9062, Test Acc : 71.1100
# Iteration : 300 - Train Loss : 1.7168, Test Loss : 1.7478, Train Acc : 74.2188, Test Acc : 71.1400
# Epoch 3121 Started...
# Iteration : 100 - Train Loss : 1.6799, Test Loss : 1.7537, Train Acc : 78.1250, Test Acc : 70.5900
# Iteration : 200 - Train Loss : 1.7468, Test Loss : 1.7471, Train Acc : 71.8750, Test Acc : 71.2400
# Iteration : 300 - Train Loss : 1.7582, Test Loss : 1.7486, Train Acc : 70.3125, Test Acc : 71.2000
# Epoch 3201 Started...
# Iteration : 100 - Train Loss : 1.7673, Test Loss : 1.7475, Train Acc : 69.5312, Test Acc : 71.3500
# Iteration : 200 - Train Loss : 1.7635, Test Loss : 1.7483, Train Acc : 70.3125, Test Acc : 71.1100
# Iteration : 300 - Train Loss : 1.6947, Test Loss : 1.7490, Train Acc : 76.5625, Test Acc : 71.0200
# Epoch 3281 Started...
# Iteration : 100 - Train Loss : 1.7252, Test Loss : 1.7479, Train Acc : 74.2188, Test Acc : 71.2100
# Iteration : 200 - Train Loss : 1.6735, Test Loss : 1.7472, Train Acc : 78.9062, Test Acc : 71.2400
# Iteration : 300 - Train Loss : 1.7144, Test Loss : 1.7470, Train Acc : 74.2188, Test Acc : 71.2900
# Epoch 3361 Started...
# Iteration : 100 - Train Loss : 1.7616, Test Loss : 1.7487, Train Acc : 69.5312, Test Acc : 71.0700
# Iteration : 200 - Train Loss : 1.7208, Test Loss : 1.7476, Train Acc : 75.0000, Test Acc : 71.1100
# Iteration : 300 - Train Loss : 1.7266, Test Loss : 1.7469, Train Acc : 73.4375, Test Acc : 71.3200
# Epoch 3441 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.6518, Test Loss : 1.7460, Train Acc : 81.2500, Test Acc : 71.4500
# Iteration : 200 - Train Loss : 1.7083, Test Loss : 1.7469, Train Acc : 74.2188, Test Acc : 71.3200
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.7916, Test Loss : 1.7434, Train Acc : 67.1875, Test Acc : 71.6600
# Epoch 3521 Started...
# Iteration : 100 - Train Loss : 1.7028, Test Loss : 1.7443, Train Acc : 75.7812, Test Acc : 71.4600
# Iteration : 200 - Train Loss : 1.7566, Test Loss : 1.7431, Train Acc : 70.3125, Test Acc : 71.5900
# Iteration : 300 - Train Loss : 1.6628, Test Loss : 1.7461, Train Acc : 80.4688, Test Acc : 71.3400
# Epoch 3601 Started...
# Iteration : 100 - Train Loss : 1.7900, Test Loss : 1.7444, Train Acc : 67.1875, Test Acc : 71.5000
# Iteration : 200 - Train Loss : 1.7736, Test Loss : 1.7456, Train Acc : 70.3125, Test Acc : 71.4100
# Iteration : 300 - Train Loss : 1.6734, Test Loss : 1.7444, Train Acc : 79.6875, Test Acc : 71.4500
# Epoch 3681 Started...
# Iteration : 100 - Train Loss : 1.7921, Test Loss : 1.7459, Train Acc : 67.1875, Test Acc : 71.4200
# Iteration : 200 - Train Loss : 1.7067, Test Loss : 1.7465, Train Acc : 75.7812, Test Acc : 71.3300
# Iteration : 300 - Train Loss : 1.6964, Test Loss : 1.7486, Train Acc : 75.7812, Test Acc : 71.0600
# Epoch 3761 Started...
# Iteration : 100 - Train Loss : 1.7551, Test Loss : 1.7451, Train Acc : 69.5312, Test Acc : 71.3800
# Iteration : 200 - Train Loss : 1.7227, Test Loss : 1.7458, Train Acc : 75.0000, Test Acc : 71.3600
# Iteration : 300 - Train Loss : 1.6886, Test Loss : 1.7453, Train Acc : 77.3438, Test Acc : 71.5300
# Epoch 3841 Started...
# Iteration : 100 - Train Loss : 1.6471, Test Loss : 1.7440, Train Acc : 81.2500, Test Acc : 71.6000
# Iteration : 200 - Train Loss : 1.7448, Test Loss : 1.7465, Train Acc : 70.3125, Test Acc : 71.3500
# Iteration : 300 - Train Loss : 1.7201, Test Loss : 1.7480, Train Acc : 73.4375, Test Acc : 71.2000
# Epoch 3921 Started...
# Iteration : 100 - Train Loss : 1.7245, Test Loss : 1.7466, Train Acc : 73.4375, Test Acc : 71.3600
# Iteration : 200 - Train Loss : 1.7556, Test Loss : 1.7449, Train Acc : 70.3125, Test Acc : 71.5900
# Iteration : 300 - Train Loss : 1.7476, Test Loss : 1.7486, Train Acc : 71.0938, Test Acc : 71.0700
# Epoch 4001 Started...
# Iteration : 100 - Train Loss : 1.7098, Test Loss : 1.7432, Train Acc : 75.0000, Test Acc : 71.5800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.7556, Test Loss : 1.7432, Train Acc : 71.0938, Test Acc : 71.6800
# Iteration : 300 - Train Loss : 1.7298, Test Loss : 1.7456, Train Acc : 72.6562, Test Acc : 71.4700
# Epoch 4081 Started...
# Iteration : 100 - Train Loss : 1.7706, Test Loss : 1.7450, Train Acc : 68.7500, Test Acc : 71.3900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.7323, Test Loss : 1.7430, Train Acc : 72.6562, Test Acc : 71.8500
# Iteration : 300 - Train Loss : 1.6957, Test Loss : 1.7425, Train Acc : 76.5625, Test Acc : 71.7700
# Epoch 4161 Started...
# Iteration : 100 - Train Loss : 1.7446, Test Loss : 1.7472, Train Acc : 71.8750, Test Acc : 71.3300
# Iteration : 200 - Train Loss : 1.7725, Test Loss : 1.7427, Train Acc : 69.5312, Test Acc : 71.6800
# Iteration : 300 - Train Loss : 1.7063, Test Loss : 1.7427, Train Acc : 75.0000, Test Acc : 71.6300
# Epoch 4241 Started...
# Iteration : 100 - Train Loss : 1.6652, Test Loss : 1.7415, Train Acc : 79.6875, Test Acc : 71.8000
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.6928, Test Loss : 1.7409, Train Acc : 76.5625, Test Acc : 71.8600
# Iteration : 300 - Train Loss : 1.6793, Test Loss : 1.7410, Train Acc : 78.9062, Test Acc : 71.8600
# Epoch 4321 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.6482, Test Loss : 1.7404, Train Acc : 81.2500, Test Acc : 71.9500
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.6923, Test Loss : 1.7403, Train Acc : 77.3438, Test Acc : 71.9600
# Iteration : 300 - Train Loss : 1.7473, Test Loss : 1.7432, Train Acc : 71.8750, Test Acc : 71.6400
# Epoch 4401 Started...
# Iteration : 100 - Train Loss : 1.7204, Test Loss : 1.7418, Train Acc : 73.4375, Test Acc : 71.8000
# Iteration : 200 - Train Loss : 1.6924, Test Loss : 1.7473, Train Acc : 76.5625, Test Acc : 71.2600
# Iteration : 300 - Train Loss : 1.7420, Test Loss : 1.7453, Train Acc : 71.0938, Test Acc : 71.5600
# Epoch 4481 Started...
# Iteration : 100 - Train Loss : 1.7610, Test Loss : 1.7413, Train Acc : 69.5312, Test Acc : 71.8300
# Iteration : 200 - Train Loss : 1.7681, Test Loss : 1.7417, Train Acc : 68.7500, Test Acc : 71.7300
# Iteration : 300 - Train Loss : 1.7791, Test Loss : 1.7439, Train Acc : 67.1875, Test Acc : 71.5500
# Epoch 4561 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.6717, Test Loss : 1.7407, Train Acc : 78.9062, Test Acc : 71.9700
# Iteration : 200 - Train Loss : 1.6375, Test Loss : 1.7405, Train Acc : 82.0312, Test Acc : 71.9300
# Iteration : 300 - Train Loss : 1.7259, Test Loss : 1.7451, Train Acc : 73.4375, Test Acc : 71.4800
# Epoch 4641 Started...
# Iteration : 100 - Train Loss : 1.7334, Test Loss : 1.7410, Train Acc : 73.4375, Test Acc : 71.8000
# Iteration : 200 - Train Loss : 1.7003, Test Loss : 1.7421, Train Acc : 75.7812, Test Acc : 71.8100
# Iteration : 300 - Train Loss : 1.7885, Test Loss : 1.7410, Train Acc : 67.1875, Test Acc : 71.8200
# Epoch 4721 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.7287, Test Loss : 1.7405, Train Acc : 73.4375, Test Acc : 71.9900
# Iteration : 200 - Train Loss : 1.7477, Test Loss : 1.7407, Train Acc : 71.0938, Test Acc : 71.9300
# Iteration : 300 - Train Loss : 1.6721, Test Loss : 1.7411, Train Acc : 78.9062, Test Acc : 71.9600
# Epoch 4801 Started...
# Iteration : 100 - Train Loss : 1.7507, Test Loss : 1.7412, Train Acc : 71.0938, Test Acc : 71.7700
# Iteration : 200 - Train Loss : 1.7700, Test Loss : 1.7427, Train Acc : 70.3125, Test Acc : 71.7400
# Iteration : 300 - Train Loss : 1.7237, Test Loss : 1.7426, Train Acc : 73.4375, Test Acc : 71.6100
# Epoch 4881 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.7238, Test Loss : 1.7401, Train Acc : 72.6562, Test Acc : 72.0300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.6345, Test Loss : 1.7398, Train Acc : 82.8125, Test Acc : 72.1700
# Iteration : 300 - Train Loss : 1.7622, Test Loss : 1.7427, Train Acc : 69.5312, Test Acc : 71.6700
# Epoch 4961 Started...
# Iteration : 100 - Train Loss : 1.7016, Test Loss : 1.7408, Train Acc : 76.5625, Test Acc : 71.7700
# Iteration : 200 - Train Loss : 1.7087, Test Loss : 1.7412, Train Acc : 75.7812, Test Acc : 71.8800
# Iteration : 300 - Train Loss : 1.7434, Test Loss : 1.7396, Train Acc : 71.8750, Test Acc : 72.0700
# Epoch 5041 Started...
# Iteration : 100 - Train Loss : 1.7220, Test Loss : 1.7431, Train Acc : 74.2188, Test Acc : 71.6900
# Iteration : 200 - Train Loss : 1.6976, Test Loss : 1.7392, Train Acc : 76.5625, Test Acc : 72.0500
# Iteration : 300 - Train Loss : 1.6967, Test Loss : 1.7399, Train Acc : 76.5625, Test Acc : 71.9800
# Epoch 5121 Started...
# Iteration : 100 - Train Loss : 1.7451, Test Loss : 1.7429, Train Acc : 70.3125, Test Acc : 71.6600
# Iteration : 200 - Train Loss : 1.7552, Test Loss : 1.7414, Train Acc : 70.3125, Test Acc : 71.9000
# Iteration : 300 - Train Loss : 1.7257, Test Loss : 1.7409, Train Acc : 73.4375, Test Acc : 71.9600
# Epoch 5201 Started...
# Iteration : 100 - Train Loss : 1.7942, Test Loss : 1.7403, Train Acc : 66.4062, Test Acc : 71.9900
# Iteration : 200 - Train Loss : 1.8400, Test Loss : 1.7422, Train Acc : 62.5000, Test Acc : 71.9000
# Iteration : 300 - Train Loss : 1.7806, Test Loss : 1.7412, Train Acc : 67.9688, Test Acc : 71.9200
# Epoch 5281 Started...
# Iteration : 100 - Train Loss : 1.7345, Test Loss : 1.7453, Train Acc : 71.0938, Test Acc : 71.4400
# Iteration : 200 - Train Loss : 1.7205, Test Loss : 1.7419, Train Acc : 74.2188, Test Acc : 71.7800
# Iteration : 300 - Train Loss : 1.6992, Test Loss : 1.7391, Train Acc : 75.7812, Test Acc : 72.0600
# Epoch 5361 Started...
# Iteration : 100 - Train Loss : 1.7901, Test Loss : 1.7400, Train Acc : 66.4062, Test Acc : 72.1400
# Iteration : 200 - Train Loss : 1.6729, Test Loss : 1.7413, Train Acc : 78.1250, Test Acc : 71.8400
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.7311, Test Loss : 1.7377, Train Acc : 73.4375, Test Acc : 72.2300
# Epoch 5441 Started...
# Iteration : 100 - Train Loss : 1.6909, Test Loss : 1.7385, Train Acc : 77.3438, Test Acc : 72.2100
# Iteration : 200 - Train Loss : 1.7396, Test Loss : 1.7433, Train Acc : 71.8750, Test Acc : 71.7000
# Iteration : 300 - Train Loss : 1.6896, Test Loss : 1.7445, Train Acc : 77.3438, Test Acc : 71.6500
# Epoch 5521 Started...
# Iteration : 100 - Train Loss : 1.6921, Test Loss : 1.7377, Train Acc : 76.5625, Test Acc : 72.2100
# Iteration : 200 - Train Loss : 1.7354, Test Loss : 1.7384, Train Acc : 73.4375, Test Acc : 72.1300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.7003, Test Loss : 1.7369, Train Acc : 75.7812, Test Acc : 72.2900
# Epoch 5601 Started...
# Iteration : 100 - Train Loss : 1.7228, Test Loss : 1.7403, Train Acc : 75.0000, Test Acc : 72.0400
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.8080, Test Loss : 1.7368, Train Acc : 65.6250, Test Acc : 72.3800
# Iteration : 300 - Train Loss : 1.7702, Test Loss : 1.7409, Train Acc : 68.7500, Test Acc : 71.9600
# Epoch 5681 Started...
# Iteration : 100 - Train Loss : 1.6481, Test Loss : 1.7404, Train Acc : 82.0312, Test Acc : 71.9700
# Iteration : 200 - Train Loss : 1.6924, Test Loss : 1.7417, Train Acc : 76.5625, Test Acc : 71.8900
# Iteration : 300 - Train Loss : 1.6991, Test Loss : 1.7400, Train Acc : 76.5625, Test Acc : 71.9700
# Epoch 5761 Started...
# Iteration : 100 - Train Loss : 1.7824, Test Loss : 1.7390, Train Acc : 67.9688, Test Acc : 72.1700
# Iteration : 200 - Train Loss : 1.6843, Test Loss : 1.7414, Train Acc : 77.3438, Test Acc : 71.8700
# Iteration : 300 - Train Loss : 1.6832, Test Loss : 1.7394, Train Acc : 77.3438, Test Acc : 72.0800
# Epoch 5841 Started...
# Iteration : 100 - Train Loss : 1.6898, Test Loss : 1.7396, Train Acc : 77.3438, Test Acc : 72.1400
# Iteration : 200 - Train Loss : 1.7429, Test Loss : 1.7392, Train Acc : 71.8750, Test Acc : 72.1900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.7352, Test Loss : 1.7370, Train Acc : 72.6562, Test Acc : 72.4300
# Epoch 5921 Started...
# Iteration : 100 - Train Loss : 1.6945, Test Loss : 1.7394, Train Acc : 77.3438, Test Acc : 72.1200
# Iteration : 200 - Train Loss : 1.7067, Test Loss : 1.7380, Train Acc : 75.0000, Test Acc : 72.2600
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.7935, Test Loss : 1.7356, Train Acc : 67.1875, Test Acc : 72.5300
# Epoch 6001 Started...
# Iteration : 100 - Train Loss : 1.7077, Test Loss : 1.7374, Train Acc : 75.7812, Test Acc : 72.2200
# Iteration : 200 - Train Loss : 1.6902, Test Loss : 1.7389, Train Acc : 77.3438, Test Acc : 72.1100
# Iteration : 300 - Train Loss : 1.6573, Test Loss : 1.7377, Train Acc : 81.2500, Test Acc : 72.2800
# Epoch 6081 Started...
# Iteration : 100 - Train Loss : 1.7545, Test Loss : 1.7399, Train Acc : 70.3125, Test Acc : 72.1200
# Iteration : 200 - Train Loss : 1.7067, Test Loss : 1.7382, Train Acc : 75.7812, Test Acc : 72.2600
# Iteration : 300 - Train Loss : 1.7272, Test Loss : 1.7392, Train Acc : 73.4375, Test Acc : 72.1200
# Epoch 6161 Started...
# Iteration : 100 - Train Loss : 1.6888, Test Loss : 1.7408, Train Acc : 77.3438, Test Acc : 71.9900
# Iteration : 200 - Train Loss : 1.7013, Test Loss : 1.7388, Train Acc : 75.7812, Test Acc : 72.2100
# Iteration : 300 - Train Loss : 1.7335, Test Loss : 1.7379, Train Acc : 72.6562, Test Acc : 72.2600
# Epoch 6241 Started...
# Iteration : 100 - Train Loss : 1.7495, Test Loss : 1.7376, Train Acc : 71.0938, Test Acc : 72.2100
# Iteration : 200 - Train Loss : 1.6617, Test Loss : 1.7379, Train Acc : 80.4688, Test Acc : 72.1900
# Iteration : 300 - Train Loss : 1.7543, Test Loss : 1.7365, Train Acc : 71.0938, Test Acc : 72.3800
# Epoch 6321 Started...
# Iteration : 100 - Train Loss : 1.7783, Test Loss : 1.7378, Train Acc : 69.5312, Test Acc : 72.2000
# Iteration : 200 - Train Loss : 1.7541, Test Loss : 1.7382, Train Acc : 71.0938, Test Acc : 72.2200
# Iteration : 300 - Train Loss : 1.6834, Test Loss : 1.7357, Train Acc : 77.3438, Test Acc : 72.4200
# Epoch 6401 Started...
# Iteration : 100 - Train Loss : 1.7014, Test Loss : 1.7353, Train Acc : 75.7812, Test Acc : 72.5100
# Iteration : 200 - Train Loss : 1.7334, Test Loss : 1.7353, Train Acc : 72.6562, Test Acc : 72.4000
# Iteration : 300 - Train Loss : 1.6706, Test Loss : 1.7379, Train Acc : 79.6875, Test Acc : 72.1700
# Epoch 6481 Started...
# Iteration : 100 - Train Loss : 1.7572, Test Loss : 1.7378, Train Acc : 70.3125, Test Acc : 72.3100
# Iteration : 200 - Train Loss : 1.6738, Test Loss : 1.7387, Train Acc : 78.9062, Test Acc : 72.2000
# Iteration : 300 - Train Loss : 1.6976, Test Loss : 1.7393, Train Acc : 76.5625, Test Acc : 72.0500
# Epoch 6561 Started...
# Iteration : 100 - Train Loss : 1.6602, Test Loss : 1.7373, Train Acc : 80.4688, Test Acc : 72.4100
# Iteration : 200 - Train Loss : 1.6413, Test Loss : 1.7410, Train Acc : 82.0312, Test Acc : 71.8800
# Iteration : 300 - Train Loss : 1.6738, Test Loss : 1.7371, Train Acc : 78.9062, Test Acc : 72.3700
# Epoch 6641 Started...
# Iteration : 100 - Train Loss : 1.7817, Test Loss : 1.7365, Train Acc : 67.1875, Test Acc : 72.2000
# Iteration : 200 - Train Loss : 1.6582, Test Loss : 1.7366, Train Acc : 80.4688, Test Acc : 72.4500
# Iteration : 300 - Train Loss : 1.7207, Test Loss : 1.7365, Train Acc : 74.2188, Test Acc : 72.2700
# Epoch 6721 Started...
# Iteration : 100 - Train Loss : 1.8058, Test Loss : 1.7378, Train Acc : 64.8438, Test Acc : 72.2600
# Iteration : 200 - Train Loss : 1.8125, Test Loss : 1.7378, Train Acc : 64.8438, Test Acc : 72.2400
# Iteration : 300 - Train Loss : 1.7295, Test Loss : 1.7386, Train Acc : 73.4375, Test Acc : 72.1600
# Epoch 6801 Started...
# Iteration : 100 - Train Loss : 1.7048, Test Loss : 1.7369, Train Acc : 75.0000, Test Acc : 72.2300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.7058, Test Loss : 1.7342, Train Acc : 75.0000, Test Acc : 72.6400
# Iteration : 300 - Train Loss : 1.7312, Test Loss : 1.7392, Train Acc : 73.4375, Test Acc : 72.1000
# Epoch 6881 Started...
# Iteration : 100 - Train Loss : 1.7497, Test Loss : 1.7388, Train Acc : 70.3125, Test Acc : 72.1500
# Iteration : 200 - Train Loss : 1.6831, Test Loss : 1.7357, Train Acc : 78.1250, Test Acc : 72.4500
# Iteration : 300 - Train Loss : 1.6426, Test Loss : 1.7364, Train Acc : 82.0312, Test Acc : 72.3200
# Epoch 6961 Started...
# Iteration : 100 - Train Loss : 1.7842, Test Loss : 1.7359, Train Acc : 67.9688, Test Acc : 72.3900
# Iteration : 200 - Train Loss : 1.6841, Test Loss : 1.7350, Train Acc : 78.1250, Test Acc : 72.5600
# Iteration : 300 - Train Loss : 1.7305, Test Loss : 1.7345, Train Acc : 73.4375, Test Acc : 72.5700
# Epoch 7041 Started...
# Iteration : 100 - Train Loss : 1.6932, Test Loss : 1.7386, Train Acc : 77.3438, Test Acc : 72.1800
# Iteration : 200 - Train Loss : 1.7218, Test Loss : 1.7387, Train Acc : 74.2188, Test Acc : 72.1700
# Iteration : 300 - Train Loss : 1.6736, Test Loss : 1.7380, Train Acc : 78.9062, Test Acc : 72.2000
# Epoch 7121 Started...
# Iteration : 100 - Train Loss : 1.7034, Test Loss : 1.7367, Train Acc : 75.7812, Test Acc : 72.3300
# Iteration : 200 - Train Loss : 1.6444, Test Loss : 1.7359, Train Acc : 82.0312, Test Acc : 72.3800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.7543, Test Loss : 1.7337, Train Acc : 70.3125, Test Acc : 72.6600
# Epoch 7201 Started...
# Iteration : 100 - Train Loss : 1.7636, Test Loss : 1.7360, Train Acc : 68.7500, Test Acc : 72.4000
# Iteration : 200 - Train Loss : 1.7968, Test Loss : 1.7354, Train Acc : 65.6250, Test Acc : 72.4300
# Iteration : 300 - Train Loss : 1.7172, Test Loss : 1.7362, Train Acc : 74.2188, Test Acc : 72.3800
# Epoch 7281 Started...
# Iteration : 100 - Train Loss : 1.6930, Test Loss : 1.7363, Train Acc : 76.5625, Test Acc : 72.3000
# Iteration : 200 - Train Loss : 1.6893, Test Loss : 1.7359, Train Acc : 76.5625, Test Acc : 72.4500
# Iteration : 300 - Train Loss : 1.7187, Test Loss : 1.7357, Train Acc : 74.2188, Test Acc : 72.4000
# Epoch 7361 Started...
# Iteration : 100 - Train Loss : 1.7241, Test Loss : 1.7332, Train Acc : 73.4375, Test Acc : 72.6500
# Iteration : 200 - Train Loss : 1.7592, Test Loss : 1.7346, Train Acc : 69.5312, Test Acc : 72.5300
# Iteration : 300 - Train Loss : 1.6721, Test Loss : 1.7370, Train Acc : 79.6875, Test Acc : 72.3300
# Epoch 7441 Started...
# Iteration : 100 - Train Loss : 1.6056, Test Loss : 1.7366, Train Acc : 85.9375, Test Acc : 72.4100
# Iteration : 200 - Train Loss : 1.7370, Test Loss : 1.7351, Train Acc : 71.8750, Test Acc : 72.4900
# Iteration : 300 - Train Loss : 1.6829, Test Loss : 1.7355, Train Acc : 77.3438, Test Acc : 72.4400
# Epoch 7521 Started...
# Iteration : 100 - Train Loss : 1.7121, Test Loss : 1.7352, Train Acc : 74.2188, Test Acc : 72.5200
# Iteration : 200 - Train Loss : 1.7186, Test Loss : 1.7350, Train Acc : 74.2188, Test Acc : 72.4900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.7264, Test Loss : 1.7333, Train Acc : 73.4375, Test Acc : 72.6700
# Epoch 7601 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.7037, Test Loss : 1.7327, Train Acc : 75.7812, Test Acc : 72.7700
# Iteration : 200 - Train Loss : 1.6966, Test Loss : 1.7357, Train Acc : 75.7812, Test Acc : 72.5000
# Iteration : 300 - Train Loss : 1.7373, Test Loss : 1.7370, Train Acc : 71.8750, Test Acc : 72.4100
# Epoch 7681 Started...
# Iteration : 100 - Train Loss : 1.7070, Test Loss : 1.7350, Train Acc : 75.7812, Test Acc : 72.4400
# Iteration : 200 - Train Loss : 1.7176, Test Loss : 1.7340, Train Acc : 74.2188, Test Acc : 72.5000
# Iteration : 300 - Train Loss : 1.6707, Test Loss : 1.7330, Train Acc : 78.9062, Test Acc : 72.7100
# Epoch 7761 Started...
# Iteration : 100 - Train Loss : 1.7085, Test Loss : 1.7361, Train Acc : 75.7812, Test Acc : 72.3300
# Iteration : 200 - Train Loss : 1.7412, Test Loss : 1.7348, Train Acc : 71.8750, Test Acc : 72.5400
# Iteration : 300 - Train Loss : 1.7548, Test Loss : 1.7337, Train Acc : 70.3125, Test Acc : 72.6800
# Epoch 7841 Started...
# Iteration : 100 - Train Loss : 1.7095, Test Loss : 1.7357, Train Acc : 75.0000, Test Acc : 72.3900
# Iteration : 200 - Train Loss : 1.7095, Test Loss : 1.7366, Train Acc : 75.0000, Test Acc : 72.3700
# Iteration : 300 - Train Loss : 1.6736, Test Loss : 1.7339, Train Acc : 79.6875, Test Acc : 72.6200
# Epoch 7921 Started...
# Iteration : 100 - Train Loss : 1.6834, Test Loss : 1.7346, Train Acc : 77.3438, Test Acc : 72.6000
# Iteration : 200 - Train Loss : 1.7805, Test Loss : 1.7378, Train Acc : 67.9688, Test Acc : 72.2000
# Iteration : 300 - Train Loss : 1.6662, Test Loss : 1.7351, Train Acc : 79.6875, Test Acc : 72.4100
# Epoch 8001 Started...
# Iteration : 100 - Train Loss : 1.6748, Test Loss : 1.7338, Train Acc : 78.1250, Test Acc : 72.7500
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.7044, Test Loss : 1.7326, Train Acc : 75.7812, Test Acc : 72.8200
# Iteration : 300 - Train Loss : 1.7340, Test Loss : 1.7380, Train Acc : 71.8750, Test Acc : 72.1600

# %%
plt.figure(figsize=(20, 20))
plt.rcParams['axes.titlesize'] = 30
plt.axis('off')

label_fontsize = 25

plt.subplot(2, 1, 1)
train_lossline, = plt.plot(NIN.train_losses, label='Train')
test_lossline, = plt.plot(NIN.test_losses, color='red', label='Test')
plt.legend(handles=[train_lossline, test_lossline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Loss', fontsize=label_fontsize)

plt.subplot(2, 1, 2)
train_accline, = plt.plot(NIN.train_acc, label='Train')
test_accline, = plt.plot(NIN.test_acc, color='red', label='Test')
plt.legend(handles=[train_accline, test_accline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Accuracy', fontsize=label_fontsize)
# Out:
# Text(0, 0.5, 'Accuracy')
