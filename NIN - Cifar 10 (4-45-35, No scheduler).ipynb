# %% [markdown]
# # NIN
#
# # 1. Environment Setup
# ## 1.0. Check GPU

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0

# %% [markdown]
# ## 1.1. Install Pytorch and torchvision

# %%
# !pip install torch==1.7.1+cu110 torchvision==0.8.2+cu110 torchaudio===0.7.2 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: torch==1.7.1+cu110 in /usr/local/lib/python3.6/dist-packages (1.7.1+cu110)
# Requirement already satisfied: torchvision==0.8.2+cu110 in /usr/local/lib/python3.6/dist-packages (0.8.2+cu110)
# Requirement already satisfied: torchaudio===0.7.2 in /usr/local/lib/python3.6/dist-packages (0.7.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch==1.7.1+cu110) (3.7.4.3)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from torch==1.7.1+cu110) (0.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch==1.7.1+cu110) (1.19.4)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.8.2+cu110) (8.0.1)
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# ## 1.2. Import

# %%
import train

import torch
import torchvision
import torchvision.transforms as transforms

import matplotlib.pyplot as plt

# Ignore Warning
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # 2. Data Preprocessing

# %%
batch_size = 128

# %%
train_transform = transforms.Compose([
    transforms.Pad(padding=4), transforms.Resize(45), transforms.RandomCrop(35), transforms.RandomHorizontalFlip(),
    transforms.ToTensor(), transforms.Normalize(mean=[0.4921, 0.4828, 0.4474], std=[0.1950, 0.1922, 0.1940])])

test_transform = transforms.Compose([
    transforms.Pad(padding=4), transforms.Resize(45), transforms.CenterCrop(35),
    transforms.ToTensor(), transforms.Normalize(mean=[0.4921, 0.4828, 0.4474], std=[0.1950, 0.1922, 0.1940])])

train_dataset = torchvision.datasets.CIFAR10('../Dataset/cifar10/', train=True, download=True, transform=train_transform)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)

test_dataset = torchvision.datasets.CIFAR10('../Dataset/cifar10/', train=False, download=True, transform=test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# # 3. Train Model

# %%
num_classes = 10

gpu_id = 4
print_freq = 100
epoch_print = 80

save = True
epochs = 8001

lr = 0.01
momentum = 0.9
weight_decay = 0.00001

# %%
NIN = train.NIN(num_classes=num_classes, gpu_id=gpu_id, print_freq=print_freq, epoch_print=epoch_print)

# %%
NIN.train(train_loader, test_loader, save, epochs, lr, momentum, weight_decay)
# Out:
# Epoch 1 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 2.2685, Test Loss : 2.2564, Train Acc : 16.4062, Test Acc : 17.5400
# Saved Best Model
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 2.2617, Test Loss : 2.2434, Train Acc : 18.7500, Test Acc : 19.2500
# Saved Best Model
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 2.2674, Test Loss : 2.2311, Train Acc : 19.5312, Test Acc : 21.3100
# Saved Best Model
# Epoch 81 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.9715, Test Loss : 1.9340, Train Acc : 50.0000, Test Acc : 52.2300
# Saved Best Model
# Iteration : 200 - Train Loss : 1.9806, Test Loss : 1.9436, Train Acc : 46.8750, Test Acc : 51.3300
# Iteration : 300 - Train Loss : 2.0021, Test Loss : 1.9368, Train Acc : 45.3125, Test Acc : 51.9700
# Epoch 161 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.8663, Test Loss : 1.8916, Train Acc : 59.3750, Test Acc : 56.5700
# Saved Best Model
# Iteration : 200 - Train Loss : 1.8726, Test Loss : 1.8964, Train Acc : 58.5938, Test Acc : 56.0600
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.8574, Test Loss : 1.8924, Train Acc : 60.1562, Test Acc : 56.6100
# Saved Best Model
# Epoch 241 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.9167, Test Loss : 1.8683, Train Acc : 53.9062, Test Acc : 58.8800
# Saved Best Model
# Iteration : 200 - Train Loss : 1.8484, Test Loss : 1.8736, Train Acc : 60.1562, Test Acc : 58.3600
# Iteration : 300 - Train Loss : 1.9237, Test Loss : 1.8732, Train Acc : 53.9062, Test Acc : 58.4200
# Epoch 321 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.8267, Test Loss : 1.8586, Train Acc : 64.0625, Test Acc : 59.9300
# Saved Best Model
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.8843, Test Loss : 1.8540, Train Acc : 58.5938, Test Acc : 60.3700
# Saved Best Model
# Iteration : 300 - Train Loss : 1.9209, Test Loss : 1.8577, Train Acc : 53.1250, Test Acc : 59.9000
# Epoch 401 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.8417, Test Loss : 1.8473, Train Acc : 61.7188, Test Acc : 61.0600
# Saved Best Model
# Iteration : 200 - Train Loss : 1.8553, Test Loss : 1.8574, Train Acc : 58.5938, Test Acc : 59.9800
# Iteration : 300 - Train Loss : 1.8792, Test Loss : 1.8489, Train Acc : 57.8125, Test Acc : 60.9400
# Epoch 481 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.8271, Test Loss : 1.8428, Train Acc : 64.0625, Test Acc : 61.5600
# Saved Best Model
# Iteration : 200 - Train Loss : 1.8684, Test Loss : 1.8452, Train Acc : 58.5938, Test Acc : 61.3200
# Iteration : 300 - Train Loss : 1.8173, Test Loss : 1.8426, Train Acc : 64.0625, Test Acc : 61.5200
# Epoch 561 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.8638, Test Loss : 1.8350, Train Acc : 60.1562, Test Acc : 62.3300
# Saved Best Model
# Iteration : 200 - Train Loss : 1.8817, Test Loss : 1.8410, Train Acc : 56.2500, Test Acc : 61.6700
# Iteration : 300 - Train Loss : 1.8281, Test Loss : 1.8354, Train Acc : 62.5000, Test Acc : 62.2900
# Epoch 641 Started...
# Iteration : 100 - Train Loss : 1.8825, Test Loss : 1.8371, Train Acc : 57.0312, Test Acc : 62.1000
# Iteration : 200 - Train Loss : 1.8416, Test Loss : 1.8379, Train Acc : 61.7188, Test Acc : 61.9300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.9416, Test Loss : 1.8343, Train Acc : 51.5625, Test Acc : 62.3900
# Saved Best Model
# Epoch 721 Started...
# Iteration : 100 - Train Loss : 1.7704, Test Loss : 1.8361, Train Acc : 68.7500, Test Acc : 62.2200
# Iteration : 200 - Train Loss : 1.8185, Test Loss : 1.8364, Train Acc : 64.0625, Test Acc : 62.0600
# Iteration : 300 - Train Loss : 1.9017, Test Loss : 1.8369, Train Acc : 55.4688, Test Acc : 62.1200
# Epoch 801 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.8241, Test Loss : 1.8328, Train Acc : 63.2812, Test Acc : 62.4500
# Saved Best Model
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.7306, Test Loss : 1.8320, Train Acc : 73.4375, Test Acc : 62.5400
# Saved Best Model
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.8101, Test Loss : 1.8294, Train Acc : 64.8438, Test Acc : 62.8500
# Saved Best Model
# Epoch 881 Started...
# Iteration : 100 - Train Loss : 1.9226, Test Loss : 1.8327, Train Acc : 53.9062, Test Acc : 62.4900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.8862, Test Loss : 1.8253, Train Acc : 57.8125, Test Acc : 63.3300
# Saved Best Model
# Iteration : 300 - Train Loss : 1.7714, Test Loss : 1.8288, Train Acc : 68.7500, Test Acc : 62.9700
# Epoch 961 Started...
# Iteration : 100 - Train Loss : 1.7655, Test Loss : 1.8288, Train Acc : 69.5312, Test Acc : 62.9600
# Iteration : 200 - Train Loss : 1.8625, Test Loss : 1.8282, Train Acc : 60.1562, Test Acc : 63.0100
# Iteration : 300 - Train Loss : 1.8149, Test Loss : 1.8276, Train Acc : 64.8438, Test Acc : 63.0200
# Epoch 1041 Started...
# Iteration : 100 - Train Loss : 1.8283, Test Loss : 1.8276, Train Acc : 63.2812, Test Acc : 62.9800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.7994, Test Loss : 1.8226, Train Acc : 67.1875, Test Acc : 63.6100
# Saved Best Model
# Iteration : 300 - Train Loss : 1.8698, Test Loss : 1.8268, Train Acc : 58.5938, Test Acc : 63.1800
# Epoch 1121 Started...
# Iteration : 100 - Train Loss : 1.7581, Test Loss : 1.8249, Train Acc : 69.5312, Test Acc : 63.2600
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.8429, Test Loss : 1.8209, Train Acc : 61.7188, Test Acc : 63.6900
# Saved Best Model
# Iteration : 300 - Train Loss : 1.8159, Test Loss : 1.8234, Train Acc : 64.0625, Test Acc : 63.4600
# Epoch 1201 Started...
# Iteration : 100 - Train Loss : 1.7981, Test Loss : 1.8227, Train Acc : 67.1875, Test Acc : 63.6100
# Iteration : 200 - Train Loss : 1.8378, Test Loss : 1.8270, Train Acc : 61.7188, Test Acc : 63.1000
# Iteration : 300 - Train Loss : 1.7641, Test Loss : 1.8261, Train Acc : 69.5312, Test Acc : 63.2800
# Epoch 1281 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.8304, Test Loss : 1.8205, Train Acc : 63.2812, Test Acc : 63.7400
# Saved Best Model
# Iteration : 200 - Train Loss : 1.8765, Test Loss : 1.8212, Train Acc : 58.5938, Test Acc : 63.6400
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.7826, Test Loss : 1.8200, Train Acc : 67.9688, Test Acc : 63.8400
# Saved Best Model
# Epoch 1361 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.8346, Test Loss : 1.8191, Train Acc : 61.7188, Test Acc : 63.8600
# Saved Best Model
# Iteration : 200 - Train Loss : 1.7742, Test Loss : 1.8208, Train Acc : 68.7500, Test Acc : 63.7700
# Iteration : 300 - Train Loss : 1.8182, Test Loss : 1.8200, Train Acc : 64.0625, Test Acc : 63.7800
# Epoch 1441 Started...
# Iteration : 100 - Train Loss : 1.8508, Test Loss : 1.8266, Train Acc : 60.9375, Test Acc : 63.1700
# Iteration : 200 - Train Loss : 1.7979, Test Loss : 1.8201, Train Acc : 66.4062, Test Acc : 63.8500
# Iteration : 300 - Train Loss : 1.8595, Test Loss : 1.8205, Train Acc : 59.3750, Test Acc : 63.6800
# Epoch 1521 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.8516, Test Loss : 1.8175, Train Acc : 60.1562, Test Acc : 64.0900
# Saved Best Model
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.8275, Test Loss : 1.8185, Train Acc : 63.2812, Test Acc : 64.1000
# Saved Best Model
# Iteration : 300 - Train Loss : 1.8218, Test Loss : 1.8203, Train Acc : 64.0625, Test Acc : 63.8100
# Epoch 1601 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.8414, Test Loss : 1.8168, Train Acc : 61.7188, Test Acc : 64.2300
# Saved Best Model
# Iteration : 200 - Train Loss : 1.7611, Test Loss : 1.8182, Train Acc : 70.3125, Test Acc : 63.9800
# Iteration : 300 - Train Loss : 1.8546, Test Loss : 1.8177, Train Acc : 60.9375, Test Acc : 64.0200
# Epoch 1681 Started...
# Iteration : 100 - Train Loss : 1.7987, Test Loss : 1.8190, Train Acc : 65.6250, Test Acc : 63.9100
# Iteration : 200 - Train Loss : 1.8186, Test Loss : 1.8163, Train Acc : 64.0625, Test Acc : 64.1900
# Iteration : 300 - Train Loss : 1.8272, Test Loss : 1.8187, Train Acc : 63.2812, Test Acc : 63.8700
# Epoch 1761 Started...
# Iteration : 100 - Train Loss : 1.7407, Test Loss : 1.8191, Train Acc : 71.0938, Test Acc : 63.9300
# Iteration : 200 - Train Loss : 1.7478, Test Loss : 1.8165, Train Acc : 71.0938, Test Acc : 64.1600
# Iteration : 300 - Train Loss : 1.7983, Test Loss : 1.8181, Train Acc : 66.4062, Test Acc : 64.0400
# Epoch 1841 Started...
# Iteration : 100 - Train Loss : 1.7816, Test Loss : 1.8229, Train Acc : 67.9688, Test Acc : 63.5000
# Iteration : 200 - Train Loss : 1.7968, Test Loss : 1.8203, Train Acc : 66.4062, Test Acc : 63.7400
# Iteration : 300 - Train Loss : 1.8591, Test Loss : 1.8195, Train Acc : 60.9375, Test Acc : 63.9100
# Epoch 1921 Started...
# Iteration : 100 - Train Loss : 1.7906, Test Loss : 1.8168, Train Acc : 67.1875, Test Acc : 64.1500
# Iteration : 200 - Train Loss : 1.8350, Test Loss : 1.8229, Train Acc : 62.5000, Test Acc : 63.5100
# Iteration : 300 - Train Loss : 1.8122, Test Loss : 1.8214, Train Acc : 64.8438, Test Acc : 63.6800
# Epoch 2001 Started...
# Iteration : 100 - Train Loss : 1.8054, Test Loss : 1.8164, Train Acc : 65.6250, Test Acc : 64.2200
# Iteration : 200 - Train Loss : 1.8173, Test Loss : 1.8177, Train Acc : 64.0625, Test Acc : 64.0900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.7652, Test Loss : 1.8138, Train Acc : 69.5312, Test Acc : 64.4400
# Saved Best Model
# Epoch 2081 Started...
# Iteration : 100 - Train Loss : 1.8437, Test Loss : 1.8173, Train Acc : 60.9375, Test Acc : 64.0500
# Iteration : 200 - Train Loss : 1.9045, Test Loss : 1.8165, Train Acc : 55.4688, Test Acc : 64.1500
# Iteration : 300 - Train Loss : 1.7735, Test Loss : 1.8170, Train Acc : 68.7500, Test Acc : 64.1200
# Epoch 2161 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.6943, Test Loss : 1.8139, Train Acc : 76.5625, Test Acc : 64.5500
# Saved Best Model
# Iteration : 200 - Train Loss : 1.7878, Test Loss : 1.8158, Train Acc : 67.1875, Test Acc : 64.2100
# Iteration : 300 - Train Loss : 1.7904, Test Loss : 1.8144, Train Acc : 67.1875, Test Acc : 64.4400
# Epoch 2241 Started...
# Iteration : 100 - Train Loss : 1.8392, Test Loss : 1.8147, Train Acc : 62.5000, Test Acc : 64.3600
# Iteration : 200 - Train Loss : 1.7981, Test Loss : 1.8136, Train Acc : 67.1875, Test Acc : 64.4300
# Iteration : 300 - Train Loss : 1.8507, Test Loss : 1.8150, Train Acc : 60.9375, Test Acc : 64.3600
# Epoch 2321 Started...
# Iteration : 100 - Train Loss : 1.7398, Test Loss : 1.8142, Train Acc : 71.8750, Test Acc : 64.4200
# Iteration : 200 - Train Loss : 1.7554, Test Loss : 1.8145, Train Acc : 71.0938, Test Acc : 64.3600
# Iteration : 300 - Train Loss : 1.7630, Test Loss : 1.8156, Train Acc : 69.5312, Test Acc : 64.3100
# Epoch 2401 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.7460, Test Loss : 1.8114, Train Acc : 71.0938, Test Acc : 64.7100
# Saved Best Model
# Iteration : 200 - Train Loss : 1.7415, Test Loss : 1.8134, Train Acc : 70.3125, Test Acc : 64.5900
# Iteration : 300 - Train Loss : 1.8178, Test Loss : 1.8129, Train Acc : 64.0625, Test Acc : 64.5500
# Epoch 2481 Started...
# Iteration : 100 - Train Loss : 1.7427, Test Loss : 1.8128, Train Acc : 72.6562, Test Acc : 64.4700
# Iteration : 200 - Train Loss : 1.7581, Test Loss : 1.8142, Train Acc : 71.0938, Test Acc : 64.3900
# Iteration : 300 - Train Loss : 1.7735, Test Loss : 1.8141, Train Acc : 68.7500, Test Acc : 64.3800
# Epoch 2561 Started...
# Iteration : 100 - Train Loss : 1.8503, Test Loss : 1.8126, Train Acc : 60.9375, Test Acc : 64.5700
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.8188, Test Loss : 1.8105, Train Acc : 64.8438, Test Acc : 64.8100
# Saved Best Model
# Iteration : 300 - Train Loss : 1.8025, Test Loss : 1.8116, Train Acc : 65.6250, Test Acc : 64.6800
# Epoch 2641 Started...
# Iteration : 100 - Train Loss : 1.7827, Test Loss : 1.8128, Train Acc : 67.1875, Test Acc : 64.5500
# Iteration : 200 - Train Loss : 1.8118, Test Loss : 1.8121, Train Acc : 65.6250, Test Acc : 64.6200
# Iteration : 300 - Train Loss : 1.8062, Test Loss : 1.8151, Train Acc : 66.4062, Test Acc : 64.3300
# Epoch 2721 Started...
# Iteration : 100 - Train Loss : 1.7957, Test Loss : 1.8135, Train Acc : 67.1875, Test Acc : 64.4500
# Iteration : 200 - Train Loss : 1.7454, Test Loss : 1.8120, Train Acc : 71.0938, Test Acc : 64.5700
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.7844, Test Loss : 1.8095, Train Acc : 67.9688, Test Acc : 64.8800
# Saved Best Model
# Epoch 2801 Started...
# Iteration : 100 - Train Loss : 1.7893, Test Loss : 1.8106, Train Acc : 66.4062, Test Acc : 64.7900
# Iteration : 200 - Train Loss : 1.7696, Test Loss : 1.8114, Train Acc : 69.5312, Test Acc : 64.7500
# Iteration : 300 - Train Loss : 1.8079, Test Loss : 1.8112, Train Acc : 65.6250, Test Acc : 64.6900
# Epoch 2881 Started...
# Iteration : 100 - Train Loss : 1.8094, Test Loss : 1.8128, Train Acc : 64.8438, Test Acc : 64.6200
# Iteration : 200 - Train Loss : 1.8102, Test Loss : 1.8119, Train Acc : 64.8438, Test Acc : 64.5700
# Iteration : 300 - Train Loss : 1.7359, Test Loss : 1.8115, Train Acc : 72.6562, Test Acc : 64.8000
# Epoch 2961 Started...
# Iteration : 100 - Train Loss : 1.8277, Test Loss : 1.8109, Train Acc : 63.2812, Test Acc : 64.7500
# Iteration : 200 - Train Loss : 1.7938, Test Loss : 1.8100, Train Acc : 66.4062, Test Acc : 64.7900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.7863, Test Loss : 1.8096, Train Acc : 67.1875, Test Acc : 64.9000
# Saved Best Model
# Epoch 3041 Started...
# Iteration : 100 - Train Loss : 1.8188, Test Loss : 1.8110, Train Acc : 64.0625, Test Acc : 64.7200
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.7714, Test Loss : 1.8089, Train Acc : 69.5312, Test Acc : 64.9500
# Saved Best Model
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.7842, Test Loss : 1.8074, Train Acc : 67.1875, Test Acc : 65.1400
# Saved Best Model
# Epoch 3121 Started...
# Iteration : 100 - Train Loss : 1.8230, Test Loss : 1.8158, Train Acc : 64.0625, Test Acc : 64.2900
# Iteration : 200 - Train Loss : 1.7901, Test Loss : 1.8086, Train Acc : 67.1875, Test Acc : 64.9100
# Iteration : 300 - Train Loss : 1.8168, Test Loss : 1.8091, Train Acc : 64.8438, Test Acc : 64.8400
# Epoch 3201 Started...
# Iteration : 100 - Train Loss : 1.8045, Test Loss : 1.8093, Train Acc : 65.6250, Test Acc : 64.9000
# Iteration : 200 - Train Loss : 1.8140, Test Loss : 1.8099, Train Acc : 64.8438, Test Acc : 64.9400
# Iteration : 300 - Train Loss : 1.7962, Test Loss : 1.8077, Train Acc : 66.4062, Test Acc : 65.0800
# Epoch 3281 Started...
# Iteration : 100 - Train Loss : 1.7813, Test Loss : 1.8105, Train Acc : 67.9688, Test Acc : 64.8500
# Iteration : 200 - Train Loss : 1.7159, Test Loss : 1.8087, Train Acc : 75.0000, Test Acc : 64.9500
# Iteration : 300 - Train Loss : 1.7172, Test Loss : 1.8079, Train Acc : 74.2188, Test Acc : 65.1400
# Epoch 3361 Started...
# Iteration : 100 - Train Loss : 1.7910, Test Loss : 1.8081, Train Acc : 66.4062, Test Acc : 65.0600
# Iteration : 200 - Train Loss : 1.8316, Test Loss : 1.8112, Train Acc : 62.5000, Test Acc : 64.7800
# Iteration : 300 - Train Loss : 1.7363, Test Loss : 1.8082, Train Acc : 72.6562, Test Acc : 65.0300
# Epoch 3441 Started...
# Iteration : 100 - Train Loss : 1.7548, Test Loss : 1.8090, Train Acc : 70.3125, Test Acc : 64.8900
# Iteration : 200 - Train Loss : 1.8738, Test Loss : 1.8094, Train Acc : 58.5938, Test Acc : 64.9500
# Iteration : 300 - Train Loss : 1.7886, Test Loss : 1.8118, Train Acc : 67.1875, Test Acc : 64.6300
# Epoch 3521 Started...
# Iteration : 100 - Train Loss : 1.7982, Test Loss : 1.8091, Train Acc : 66.4062, Test Acc : 64.9300
# Iteration : 200 - Train Loss : 1.7145, Test Loss : 1.8087, Train Acc : 75.0000, Test Acc : 64.9400
# Iteration : 300 - Train Loss : 1.7857, Test Loss : 1.8116, Train Acc : 67.9688, Test Acc : 64.6100
# Epoch 3601 Started...
# Iteration : 100 - Train Loss : 1.7930, Test Loss : 1.8149, Train Acc : 67.1875, Test Acc : 64.2700
# Iteration : 200 - Train Loss : 1.8759, Test Loss : 1.8096, Train Acc : 58.5938, Test Acc : 64.8500
# Iteration : 300 - Train Loss : 1.7878, Test Loss : 1.8091, Train Acc : 67.1875, Test Acc : 64.9500
# Epoch 3681 Started...
# Iteration : 100 - Train Loss : 1.8177, Test Loss : 1.8087, Train Acc : 64.0625, Test Acc : 65.0000
# Iteration : 200 - Train Loss : 1.7730, Test Loss : 1.8099, Train Acc : 68.7500, Test Acc : 64.7800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.8017, Test Loss : 1.8071, Train Acc : 65.6250, Test Acc : 65.1500
# Saved Best Model
# Epoch 3761 Started...
# Iteration : 100 - Train Loss : 1.7897, Test Loss : 1.8082, Train Acc : 67.1875, Test Acc : 64.9400
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.8090, Test Loss : 1.8074, Train Acc : 64.8438, Test Acc : 65.1900
# Saved Best Model
# Iteration : 300 - Train Loss : 1.8367, Test Loss : 1.8082, Train Acc : 62.5000, Test Acc : 65.0100
# Epoch 3841 Started...
# Iteration : 100 - Train Loss : 1.7978, Test Loss : 1.8094, Train Acc : 65.6250, Test Acc : 64.8700
# Iteration : 200 - Train Loss : 1.7987, Test Loss : 1.8100, Train Acc : 65.6250, Test Acc : 64.9200
# Iteration : 300 - Train Loss : 1.7963, Test Loss : 1.8070, Train Acc : 67.1875, Test Acc : 65.0800
# Epoch 3921 Started...
# Iteration : 100 - Train Loss : 1.7296, Test Loss : 1.8070, Train Acc : 72.6562, Test Acc : 65.1200
# Iteration : 200 - Train Loss : 1.7951, Test Loss : 1.8085, Train Acc : 67.1875, Test Acc : 64.9400
# Iteration : 300 - Train Loss : 1.7753, Test Loss : 1.8072, Train Acc : 68.7500, Test Acc : 65.1400
# Epoch 4001 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.8449, Test Loss : 1.8062, Train Acc : 60.9375, Test Acc : 65.2700
# Saved Best Model
# Iteration : 200 - Train Loss : 1.8112, Test Loss : 1.8054, Train Acc : 64.8438, Test Acc : 65.2700
# Iteration : 300 - Train Loss : 1.8007, Test Loss : 1.8080, Train Acc : 64.8438, Test Acc : 65.1300
# Epoch 4081 Started...
# Iteration : 100 - Train Loss : 1.7797, Test Loss : 1.8083, Train Acc : 67.9688, Test Acc : 64.9800
# Iteration : 200 - Train Loss : 1.7790, Test Loss : 1.8075, Train Acc : 67.9688, Test Acc : 65.0700
# Iteration : 300 - Train Loss : 1.7963, Test Loss : 1.8075, Train Acc : 66.4062, Test Acc : 65.1200
# Epoch 4161 Started...
# Iteration : 100 - Train Loss : 1.8122, Test Loss : 1.8061, Train Acc : 64.8438, Test Acc : 65.1700
# Iteration : 200 - Train Loss : 1.7301, Test Loss : 1.8064, Train Acc : 73.4375, Test Acc : 65.1900
# Iteration : 300 - Train Loss : 1.8740, Test Loss : 1.8111, Train Acc : 58.5938, Test Acc : 64.6700
# Epoch 4241 Started...
# Iteration : 100 - Train Loss : 1.8688, Test Loss : 1.8083, Train Acc : 58.5938, Test Acc : 65.0200
# Iteration : 200 - Train Loss : 1.7875, Test Loss : 1.8083, Train Acc : 67.1875, Test Acc : 64.9500
# Iteration : 300 - Train Loss : 1.8074, Test Loss : 1.8075, Train Acc : 64.8438, Test Acc : 65.0500
# Epoch 4321 Started...
# Iteration : 100 - Train Loss : 1.8100, Test Loss : 1.8061, Train Acc : 64.8438, Test Acc : 65.1200
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.8176, Test Loss : 1.8041, Train Acc : 64.0625, Test Acc : 65.3800
# Saved Best Model
# Iteration : 300 - Train Loss : 1.8064, Test Loss : 1.8066, Train Acc : 65.6250, Test Acc : 65.0600
# Epoch 4401 Started...
# Iteration : 100 - Train Loss : 1.8131, Test Loss : 1.8076, Train Acc : 64.0625, Test Acc : 65.0900
# Iteration : 200 - Train Loss : 1.8217, Test Loss : 1.8064, Train Acc : 64.0625, Test Acc : 65.1900
# Iteration : 300 - Train Loss : 1.7743, Test Loss : 1.8061, Train Acc : 68.7500, Test Acc : 65.2300
# Epoch 4481 Started...
# Iteration : 100 - Train Loss : 1.8200, Test Loss : 1.8085, Train Acc : 64.0625, Test Acc : 64.9700
# Iteration : 200 - Train Loss : 1.7632, Test Loss : 1.8053, Train Acc : 70.3125, Test Acc : 65.3000
# Iteration : 300 - Train Loss : 1.7893, Test Loss : 1.8071, Train Acc : 66.4062, Test Acc : 65.1600
# Epoch 4561 Started...
# Iteration : 100 - Train Loss : 1.7867, Test Loss : 1.8062, Train Acc : 67.1875, Test Acc : 65.2200
# Iteration : 200 - Train Loss : 1.7796, Test Loss : 1.8074, Train Acc : 67.9688, Test Acc : 64.9500
# Iteration : 300 - Train Loss : 1.8177, Test Loss : 1.8095, Train Acc : 64.0625, Test Acc : 64.8100
# Epoch 4641 Started...
# Iteration : 100 - Train Loss : 1.7647, Test Loss : 1.8076, Train Acc : 69.5312, Test Acc : 65.0400
# Iteration : 200 - Train Loss : 1.7753, Test Loss : 1.8098, Train Acc : 68.7500, Test Acc : 64.7300
# Iteration : 300 - Train Loss : 1.7560, Test Loss : 1.8103, Train Acc : 70.3125, Test Acc : 64.7100
# Epoch 4721 Started...
# Iteration : 100 - Train Loss : 1.7786, Test Loss : 1.8078, Train Acc : 67.9688, Test Acc : 65.0700
# Iteration : 200 - Train Loss : 1.7155, Test Loss : 1.8067, Train Acc : 74.2188, Test Acc : 65.1900
# Iteration : 300 - Train Loss : 1.8511, Test Loss : 1.8067, Train Acc : 60.9375, Test Acc : 65.1000
# Epoch 4801 Started...
# Iteration : 100 - Train Loss : 1.7600, Test Loss : 1.8088, Train Acc : 70.3125, Test Acc : 65.0800
# Iteration : 200 - Train Loss : 1.7578, Test Loss : 1.8067, Train Acc : 70.3125, Test Acc : 65.2000
# Iteration : 300 - Train Loss : 1.7619, Test Loss : 1.8068, Train Acc : 69.5312, Test Acc : 65.1100
# Epoch 4881 Started...
# Iteration : 100 - Train Loss : 1.7221, Test Loss : 1.8088, Train Acc : 73.4375, Test Acc : 64.9000
# Iteration : 200 - Train Loss : 1.7437, Test Loss : 1.8100, Train Acc : 72.6562, Test Acc : 64.8200
# Iteration : 300 - Train Loss : 1.7463, Test Loss : 1.8058, Train Acc : 71.8750, Test Acc : 65.2200
# Epoch 4961 Started...
# Iteration : 100 - Train Loss : 1.8271, Test Loss : 1.8075, Train Acc : 63.2812, Test Acc : 65.0600
# Iteration : 200 - Train Loss : 1.7769, Test Loss : 1.8084, Train Acc : 67.9688, Test Acc : 65.0300
# Iteration : 300 - Train Loss : 1.8169, Test Loss : 1.8124, Train Acc : 64.0625, Test Acc : 64.5600
# Epoch 5041 Started...
# Iteration : 100 - Train Loss : 1.7146, Test Loss : 1.8055, Train Acc : 74.2188, Test Acc : 65.2100
# Iteration : 200 - Train Loss : 1.7464, Test Loss : 1.8081, Train Acc : 71.8750, Test Acc : 65.0300
# Iteration : 300 - Train Loss : 1.7798, Test Loss : 1.8083, Train Acc : 67.9688, Test Acc : 64.8500
# Epoch 5121 Started...
# Iteration : 100 - Train Loss : 1.7963, Test Loss : 1.8082, Train Acc : 65.6250, Test Acc : 64.9900
# Iteration : 200 - Train Loss : 1.8221, Test Loss : 1.8063, Train Acc : 63.2812, Test Acc : 65.1900
# Iteration : 300 - Train Loss : 1.7434, Test Loss : 1.8065, Train Acc : 71.0938, Test Acc : 65.1900
# Epoch 5201 Started...
# Iteration : 100 - Train Loss : 1.7905, Test Loss : 1.8109, Train Acc : 66.4062, Test Acc : 64.7900
# Iteration : 200 - Train Loss : 1.7216, Test Loss : 1.8071, Train Acc : 74.2188, Test Acc : 65.1900
# Iteration : 300 - Train Loss : 1.8765, Test Loss : 1.8061, Train Acc : 58.5938, Test Acc : 65.2400
# Epoch 5281 Started...
# Iteration : 100 - Train Loss : 1.7504, Test Loss : 1.8057, Train Acc : 70.3125, Test Acc : 65.3100
# Iteration : 200 - Train Loss : 1.7462, Test Loss : 1.8056, Train Acc : 71.8750, Test Acc : 65.2800
# Iteration : 300 - Train Loss : 1.7953, Test Loss : 1.8065, Train Acc : 66.4062, Test Acc : 65.0800
# Epoch 5361 Started...
# Iteration : 100 - Train Loss : 1.7998, Test Loss : 1.8070, Train Acc : 66.4062, Test Acc : 65.1200
# Iteration : 200 - Train Loss : 1.8450, Test Loss : 1.8087, Train Acc : 60.9375, Test Acc : 64.7600
# Iteration : 300 - Train Loss : 1.8131, Test Loss : 1.8067, Train Acc : 64.8438, Test Acc : 65.1500
# Epoch 5441 Started...
# Iteration : 100 - Train Loss : 1.8019, Test Loss : 1.8056, Train Acc : 66.4062, Test Acc : 65.2700
# Iteration : 200 - Train Loss : 1.7596, Test Loss : 1.8087, Train Acc : 70.3125, Test Acc : 64.9200
# Iteration : 300 - Train Loss : 1.7846, Test Loss : 1.8079, Train Acc : 67.1875, Test Acc : 65.0000
# Epoch 5521 Started...
# Iteration : 100 - Train Loss : 1.7399, Test Loss : 1.8080, Train Acc : 72.6562, Test Acc : 64.9900
# Iteration : 200 - Train Loss : 1.7146, Test Loss : 1.8060, Train Acc : 74.2188, Test Acc : 65.1500
# Iteration : 300 - Train Loss : 1.8761, Test Loss : 1.8070, Train Acc : 59.3750, Test Acc : 65.1000
# Epoch 5601 Started...
# Iteration : 100 - Train Loss : 1.7881, Test Loss : 1.8066, Train Acc : 67.1875, Test Acc : 65.1300
# Iteration : 200 - Train Loss : 1.7608, Test Loss : 1.8069, Train Acc : 70.3125, Test Acc : 65.0800
# Iteration : 300 - Train Loss : 1.8017, Test Loss : 1.8105, Train Acc : 65.6250, Test Acc : 64.7700
# Epoch 5681 Started...
# Iteration : 100 - Train Loss : 1.7828, Test Loss : 1.8063, Train Acc : 67.9688, Test Acc : 65.0600
# Iteration : 200 - Train Loss : 1.8226, Test Loss : 1.8057, Train Acc : 63.2812, Test Acc : 65.2900
# Iteration : 300 - Train Loss : 1.7578, Test Loss : 1.8073, Train Acc : 70.3125, Test Acc : 65.1100
# Epoch 5761 Started...
# Iteration : 100 - Train Loss : 1.7799, Test Loss : 1.8086, Train Acc : 67.9688, Test Acc : 64.9000
# Iteration : 200 - Train Loss : 1.7527, Test Loss : 1.8059, Train Acc : 70.3125, Test Acc : 65.2200
# Iteration : 300 - Train Loss : 1.7983, Test Loss : 1.8097, Train Acc : 66.4062, Test Acc : 64.7800
# Epoch 5841 Started...
# Iteration : 100 - Train Loss : 1.7965, Test Loss : 1.8058, Train Acc : 66.4062, Test Acc : 65.1900
# Iteration : 200 - Train Loss : 1.8257, Test Loss : 1.8061, Train Acc : 64.0625, Test Acc : 65.1500
# Iteration : 300 - Train Loss : 1.7365, Test Loss : 1.8078, Train Acc : 71.8750, Test Acc : 65.0100
# Epoch 5921 Started...
# Iteration : 100 - Train Loss : 1.7240, Test Loss : 1.8078, Train Acc : 73.4375, Test Acc : 65.0300
# Iteration : 200 - Train Loss : 1.7982, Test Loss : 1.8069, Train Acc : 65.6250, Test Acc : 65.1000
# Iteration : 300 - Train Loss : 1.7841, Test Loss : 1.8073, Train Acc : 67.9688, Test Acc : 65.0500
# Epoch 6001 Started...
# Iteration : 100 - Train Loss : 1.8131, Test Loss : 1.8067, Train Acc : 64.0625, Test Acc : 65.1600
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.7409, Test Loss : 1.8042, Train Acc : 71.8750, Test Acc : 65.4400
# Saved Best Model
# Iteration : 300 - Train Loss : 1.7306, Test Loss : 1.8054, Train Acc : 72.6562, Test Acc : 65.2800
# Epoch 6081 Started...
# Iteration : 100 - Train Loss : 1.8515, Test Loss : 1.8067, Train Acc : 60.9375, Test Acc : 65.1400
# Iteration : 200 - Train Loss : 1.7892, Test Loss : 1.8078, Train Acc : 67.1875, Test Acc : 64.9500
# Iteration : 300 - Train Loss : 1.7078, Test Loss : 1.8070, Train Acc : 75.0000, Test Acc : 65.0900
# Epoch 6161 Started...
# Iteration : 100 - Train Loss : 1.7901, Test Loss : 1.8069, Train Acc : 67.1875, Test Acc : 65.2300
# Iteration : 200 - Train Loss : 1.7487, Test Loss : 1.8084, Train Acc : 71.0938, Test Acc : 65.0000
# Iteration : 300 - Train Loss : 1.7402, Test Loss : 1.8080, Train Acc : 72.6562, Test Acc : 65.0500
# Epoch 6241 Started...
# Iteration : 100 - Train Loss : 1.7265, Test Loss : 1.8046, Train Acc : 73.4375, Test Acc : 65.3900
# Iteration : 200 - Train Loss : 1.7795, Test Loss : 1.8056, Train Acc : 67.9688, Test Acc : 65.2500
# Iteration : 300 - Train Loss : 1.7855, Test Loss : 1.8081, Train Acc : 67.1875, Test Acc : 64.9200
# Epoch 6321 Started...
# Iteration : 100 - Train Loss : 1.7714, Test Loss : 1.8056, Train Acc : 69.5312, Test Acc : 65.2700
# Iteration : 200 - Train Loss : 1.7523, Test Loss : 1.8051, Train Acc : 71.0938, Test Acc : 65.3300
# Iteration : 300 - Train Loss : 1.7702, Test Loss : 1.8036, Train Acc : 68.7500, Test Acc : 65.4200
# Epoch 6401 Started...
# Iteration : 100 - Train Loss : 1.7332, Test Loss : 1.8062, Train Acc : 72.6562, Test Acc : 65.1700
# Iteration : 200 - Train Loss : 1.7590, Test Loss : 1.8057, Train Acc : 70.3125, Test Acc : 65.1700
# Iteration : 300 - Train Loss : 1.8162, Test Loss : 1.8057, Train Acc : 64.0625, Test Acc : 65.2300
# Epoch 6481 Started...
# Iteration : 100 - Train Loss : 1.7264, Test Loss : 1.8051, Train Acc : 73.4375, Test Acc : 65.2600
# Iteration : 200 - Train Loss : 1.8000, Test Loss : 1.8057, Train Acc : 66.4062, Test Acc : 65.1500
# Iteration : 300 - Train Loss : 1.8467, Test Loss : 1.8060, Train Acc : 60.9375, Test Acc : 65.1600
# Epoch 6561 Started...
# Iteration : 100 - Train Loss : 1.7536, Test Loss : 1.8072, Train Acc : 71.0938, Test Acc : 65.0900
# Iteration : 200 - Train Loss : 1.7938, Test Loss : 1.8059, Train Acc : 66.4062, Test Acc : 65.1600
# Iteration : 300 - Train Loss : 1.7974, Test Loss : 1.8055, Train Acc : 65.6250, Test Acc : 65.2500
# Epoch 6641 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.7542, Test Loss : 1.8047, Train Acc : 70.3125, Test Acc : 65.4600
# Saved Best Model
# Iteration : 200 - Train Loss : 1.7854, Test Loss : 1.8059, Train Acc : 67.1875, Test Acc : 65.1600
# Iteration : 300 - Train Loss : 1.7875, Test Loss : 1.8054, Train Acc : 67.1875, Test Acc : 65.2100
# Epoch 6721 Started...
# Iteration : 100 - Train Loss : 1.7376, Test Loss : 1.8048, Train Acc : 71.8750, Test Acc : 65.4300
# Iteration : 200 - Train Loss : 1.8228, Test Loss : 1.8042, Train Acc : 64.0625, Test Acc : 65.3800
# Iteration : 300 - Train Loss : 1.7264, Test Loss : 1.8055, Train Acc : 73.4375, Test Acc : 65.2500
# Epoch 6801 Started...
# Iteration : 100 - Train Loss : 1.7742, Test Loss : 1.8065, Train Acc : 67.9688, Test Acc : 65.1600
# Iteration : 200 - Train Loss : 1.7798, Test Loss : 1.8087, Train Acc : 67.9688, Test Acc : 64.8800
# Iteration : 300 - Train Loss : 1.7583, Test Loss : 1.8063, Train Acc : 70.3125, Test Acc : 65.1700
# Epoch 6881 Started...
# Iteration : 100 - Train Loss : 1.8189, Test Loss : 1.8083, Train Acc : 64.0625, Test Acc : 65.0200
# Iteration : 200 - Train Loss : 1.7662, Test Loss : 1.8064, Train Acc : 68.7500, Test Acc : 65.1700
# Iteration : 300 - Train Loss : 1.7898, Test Loss : 1.8060, Train Acc : 66.4062, Test Acc : 65.2200
# Epoch 6961 Started...
# Iteration : 100 - Train Loss : 1.7605, Test Loss : 1.8057, Train Acc : 70.3125, Test Acc : 65.1900
# Iteration : 200 - Train Loss : 1.7237, Test Loss : 1.8049, Train Acc : 73.4375, Test Acc : 65.2000
# Iteration : 300 - Train Loss : 1.8021, Test Loss : 1.8074, Train Acc : 65.6250, Test Acc : 65.0500
# Epoch 7041 Started...
# Iteration : 100 - Train Loss : 1.7579, Test Loss : 1.8053, Train Acc : 70.3125, Test Acc : 65.2600
# Iteration : 200 - Train Loss : 1.7910, Test Loss : 1.8040, Train Acc : 67.1875, Test Acc : 65.4600
# Iteration : 300 - Train Loss : 1.7468, Test Loss : 1.8030, Train Acc : 71.0938, Test Acc : 65.4600
# Epoch 7121 Started...
# Iteration : 100 - Train Loss : 1.8225, Test Loss : 1.8061, Train Acc : 64.0625, Test Acc : 65.0400
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 200 - Train Loss : 1.7687, Test Loss : 1.8026, Train Acc : 68.7500, Test Acc : 65.4700
# Saved Best Model
# Iteration : 300 - Train Loss : 1.8439, Test Loss : 1.8048, Train Acc : 61.7188, Test Acc : 65.2600
# Epoch 7201 Started...
# Iteration : 100 - Train Loss : 1.7790, Test Loss : 1.8071, Train Acc : 67.9688, Test Acc : 65.0500
# Iteration : 200 - Train Loss : 1.7856, Test Loss : 1.8049, Train Acc : 67.1875, Test Acc : 65.3100
# Iteration : 300 - Train Loss : 1.7919, Test Loss : 1.8054, Train Acc : 67.1875, Test Acc : 65.1400
# Epoch 7281 Started...
# Iteration : 100 - Train Loss : 1.7889, Test Loss : 1.8037, Train Acc : 67.1875, Test Acc : 65.3200
# Iteration : 200 - Train Loss : 1.7909, Test Loss : 1.8042, Train Acc : 66.4062, Test Acc : 65.2100
# Iteration : 300 - Train Loss : 1.8076, Test Loss : 1.8052, Train Acc : 64.8438, Test Acc : 65.2700
# Epoch 7361 Started...
# Iteration : 100 - Train Loss : 1.7629, Test Loss : 1.8040, Train Acc : 70.3125, Test Acc : 65.4200
# Iteration : 200 - Train Loss : 1.7516, Test Loss : 1.8048, Train Acc : 70.3125, Test Acc : 65.3400
# Iteration : 300 - Train Loss : 1.7728, Test Loss : 1.8033, Train Acc : 68.7500, Test Acc : 65.4200
# Epoch 7441 Started...
# Iteration : 100 - Train Loss : 1.7951, Test Loss : 1.8051, Train Acc : 66.4062, Test Acc : 65.1800
# Iteration : 200 - Train Loss : 1.7805, Test Loss : 1.8053, Train Acc : 67.9688, Test Acc : 65.1800
# Iteration : 300 - Train Loss : 1.7962, Test Loss : 1.8041, Train Acc : 66.4062, Test Acc : 65.2500
# Epoch 7521 Started...
# Iteration : 100 - Train Loss : 1.7215, Test Loss : 1.8045, Train Acc : 74.2188, Test Acc : 65.2700
# Iteration : 200 - Train Loss : 1.8019, Test Loss : 1.8037, Train Acc : 65.6250, Test Acc : 65.3600
# Iteration : 300 - Train Loss : 1.8006, Test Loss : 1.8046, Train Acc : 65.6250, Test Acc : 65.2900
# Epoch 7601 Started...
# Iteration : 100 - Train Loss : 1.8064, Test Loss : 1.8052, Train Acc : 64.8438, Test Acc : 65.2100
# Iteration : 200 - Train Loss : 1.7453, Test Loss : 1.8033, Train Acc : 71.0938, Test Acc : 65.4600
# Iteration : 300 - Train Loss : 1.8012, Test Loss : 1.8036, Train Acc : 65.6250, Test Acc : 65.4300
# Epoch 7681 Started...
# Iteration : 100 - Train Loss : 1.7477, Test Loss : 1.8037, Train Acc : 71.0938, Test Acc : 65.3900
# Iteration : 200 - Train Loss : 1.7629, Test Loss : 1.8033, Train Acc : 69.5312, Test Acc : 65.3700
# Iteration : 300 - Train Loss : 1.7713, Test Loss : 1.8040, Train Acc : 68.7500, Test Acc : 65.3500
# Epoch 7761 Started...
# Iteration : 100 - Train Loss : 1.7247, Test Loss : 1.8036, Train Acc : 73.4375, Test Acc : 65.3800
# Iteration : 200 - Train Loss : 1.7316, Test Loss : 1.8042, Train Acc : 72.6562, Test Acc : 65.3200
# Iteration : 300 - Train Loss : 1.7041, Test Loss : 1.8052, Train Acc : 75.7812, Test Acc : 65.1200
# Epoch 7841 Started...
# Iteration : 100 - Train Loss : 1.7525, Test Loss : 1.8024, Train Acc : 71.0938, Test Acc : 65.4700
# Iteration : 200 - Train Loss : 1.7976, Test Loss : 1.8041, Train Acc : 65.6250, Test Acc : 65.3000
# Iteration : 300 - Train Loss : 1.7658, Test Loss : 1.8056, Train Acc : 68.7500, Test Acc : 65.2100
# Epoch 7921 Started...
# Iteration : 100 - Train Loss : 1.7516, Test Loss : 1.8055, Train Acc : 71.0938, Test Acc : 65.0800
# Iteration : 200 - Train Loss : 1.7810, Test Loss : 1.8050, Train Acc : 67.1875, Test Acc : 65.2500
# Iteration : 300 - Train Loss : 1.7628, Test Loss : 1.8037, Train Acc : 69.5312, Test Acc : 65.2600
# Epoch 8001 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 100 - Train Loss : 1.6566, Test Loss : 1.8023, Train Acc : 80.4688, Test Acc : 65.4900
# Saved Best Model
# Iteration : 200 - Train Loss : 1.7564, Test Loss : 1.8048, Train Acc : 70.3125, Test Acc : 65.3000
# Iteration : 300 - Train Loss : 1.7699, Test Loss : 1.8064, Train Acc : 68.7500, Test Acc : 65.1400

# %%
plt.figure(figsize=(20, 20))
plt.rcParams['axes.titlesize'] = 30
plt.axis('off')

label_fontsize = 25

plt.subplot(2, 1, 1)
train_lossline, = plt.plot(NIN.train_losses, label='Train')
test_lossline, = plt.plot(NIN.test_losses, color='red', label='Test')
plt.legend(handles=[train_lossline, test_lossline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Loss', fontsize=label_fontsize)

plt.subplot(2, 1, 2)
train_accline, = plt.plot(NIN.train_acc, label='Train')
test_accline, = plt.plot(NIN.test_acc, color='red', label='Test')
plt.legend(handles=[train_accline, test_accline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Accuracy', fontsize=label_fontsize)
# Out:
# Text(0, 0.5, 'Accuracy')
